# %% [markdown]
# # Gallstone Final Report
# - **Group 18**
#     - Timothy
#     - Elmeri
#     - Pony
#     - Miguel
# - **STAT 301**
# - **Dec 6 2025**

# %% [markdown]
# ## Introduction
# #### Summary
# - The dataset assigned to our group is about Gallstone Disease by Esen, Irfan, et al. It contains bioimpedance and laboratory data to develop machine learning models for predicting gallstone disease, which was served as an alternative diagnostic approach to traditional imaging techniques such as ultrasonography, CT, and MRI (Esen, Irfan, et al.). Specifically, the dataset contains 319 observations of which 161 are gallstone patients and 158 are healthy controls (Esen, Irfan, et al.). Furthermore, the dataset includes 38 variables with no missing values (Esen, Irfan, et al.), and their name and type are given in the bullet points below:
#     - **Name (Type): Description**
#     - Gallstone Status (Binary): Target variable, Gallstones present(0), and absent(1)
#     - Age (Integer): Age of the person (years)
#     - Gender (Categorical): Gender of the person
#     - Comorbidity (Categorical): Concomitant disease
#     - Coronary Artery Disease (Binary): Cardiovascular
#     - Hypothyroidism (Binary): Underactive thyroid gland
#     - Hyperlipidemia (Binary): High levels of fat in the blood
#     - Diabetes Mellitus (Binary): High blood sugar
#     - Height (Integer): Height is the length (cm)
#     - Weight (Continuous): Body weight (kg)
#     - Body Mass Index (Continuous): Weight for height ratio (kg/m$^2$)
#     - Total Body Water (Continuous): Total water in the body (kg)
#     - Extracellular Water (Continuous): Extracellular water (kg)
#     - Intracellular Water (Continuous): Intracellular water (kg)
#     - Extracellular Fluid/Total Body Water (Continuous): Extracellular water content
#     - Total Body Fat Ratio (Continuous): Total fat content (%)
#     - Lean Mass (Continuous): Lean body mass (%)
#     - Body Protein Content (Continuous): Essential building blocks for the body (%)
#     - Visceral Fat Rating (Integer): Visceral organ fat level
#     - Bone Mass (Continuous): Bone weight (kg)
#     - Muscle Mass (Continuous): Amount of muscle (kg)
#     - Obesity (Continuous): Excessive adiposity (%)
#     - Total Fat Content (Continuous): Total fat amount (kg)
#     - Visceral Fat Area (Continuous): Inner adipose tissue area (kg)
#     - Visceral Muscle Area (Continuous): Inner muscle area (kg)
#     - Hepatic Fat Accumulation (Categorical): Accumulation of fat in the liver
#     - Glucose (Continuous): Blood sugar (mg/dL)
#     - Total Cholesterol (Continuous): Total cholesterol (mg/dL)
#     - Low Density Lipoprotein (Continuous): Bad cholesterol (mg/dL)
#     - High Density Lipoprotein (Continuous): Good cholesterol (mg/dL)
#     - Triglyceride (Continuous): Type of fat found in the blood (mg/dL)
#     - Aspartat Aminostransferaz (Continuous): Type of liver enzyme (U/L)
#     - Alanin Alminostransferaz (Continuous): An enzyme related to the liver (U/L)
#     - Alkaline Phosphatase (Continuous): Type of liver and bone enzyme (U/L)
#     - Creatinine (Continuous): Kidney function indicator (mg/dL)
#     - Glomerular Filtration Rate (Continuous): Kidney filtration rate (mL/min)
#     - C-Reactive Protein (Continuous): Inflammation indicator (mg/L)
#     - Hemoglobin (Continuous): Protein in the blood that carries oxygen (g/dL)
#     - Vitamin D (Continuous): Essential vitamin for bone health (ng/mL)
#
# #### Research Focus
# - The primary focus of our question will be inference. We want to understand and quantify the relationship between each predictor and the odds of having gallstones. Specifically, we aim to determine which predictors are statistically significantly associated with gallstone disease.
#
# #### Research Question
# - Which bioimpedance measurements and laboratory biomarkers are significantly associated with gallstone disease?
#
# #### Source & Information
# - This dataset originates from a prospective descriptive study conducted at the Internal Medicine Outpatient Clinic of Ankara VM Medical Park Hospital between June 2022 and June 2023 (Esen, Irfan, et al.) From an initial 454 participants, 134 individuals who had undergone gallbladder surgery were excluded, resulting in the final dataset of 319 observations of which 161 are gallstone patients and 158 are healthy controls (Esen, Irfan, et al.).
# - **Citation**
#     - Esen, Irfan, et al. "Gallstone." UCI Machine Learning Repository, 2024, https://doi.org/10.1097/md.0000000000037258.
